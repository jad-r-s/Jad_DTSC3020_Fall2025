# %% [markdown]
# <a href="https://colab.research.google.com/github/jad-r-s/Jad_DTSC3020_Fall2025/blob/main/Student_In_Class_Assignment_Ch_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ✅ Final Class Exercise: Library Borrowing (using key-value)
# You are given a dictionary that shows how many books each student has borrowed. Write a Python program to:
# 1.  Print the names of students who borrowed more than 2 books.
# 2. calculate the total number of borrowed books.

# %%
borrowed_books = {
    'Ali': 1,
    'Sara': 3,
    'Reza': 0,
    'Lina': 4,
    'Omid': 2
}

# write your answer here part 1

for key, value in borrowed_books.items():
  if value > 2:
    print(key)

# write your answer here part 2

total = sum(borrowed_books.values())
print("Total number of borrowed books:", total)
# Out:
# Sara
# Lina
# Total number of borrowed books: 10
